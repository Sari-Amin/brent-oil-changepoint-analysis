# %%
import sys

sys.path.append("../")

from src.data_loader import DataLoader


dl = DataLoader("../data/BrentOilPrices.csv")
df = dl.load_data()
df = dl.compute_log_returns()
# Out:
# c:\Users\hp\Desktop\Projects\ML\KAIM\week-10\brent-oil-changepoint-analysis\notebooks\..\src\data_loader.py:14: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   self.df['Date'] = pd.to_datetime(self.df['Date'], dayfirst=True)

# %%
from src.model import ChangePointModel
from src.model_utils import plot_trace, plot_posterior_tau

log_returns = df['LogReturn'].dropna().values

model = ChangePointModel(log_returns)
model.build_model()
model.run_inference(draws=1000, tune=500)

trace = model.get_trace()
plot_trace(trace)
plot_posterior_tau(trace)
# Out:
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: Floor(9009)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "c:\Users\hp\Desktop\Projects\ML\KAIM\week-10\brent-oil-changepoint-analysis\env\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1922, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hp\Desktop\Projects\ML\KAIM\week-10\brent-oil-changepoint-analysis\env\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hp\Desktop\Projects\ML\KAIM\week-10\brent-oil-changepoint-analysis\env\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1160, in constant_folding
# ...
